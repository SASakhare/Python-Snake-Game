# %%
print('help')
# Out:
# help

# %%
x_b=[1,2,3]
y_b=[4,5,6]

for x,y in zip(x_b,y_b):
    print(x,y)
# Out:
# 1 4
# 2 5
# 3 6

# %%
x_b=[40 * i for i in range(1,5)]

x_b
# Out:
# [40, 80, 120, 160]

# %%
for i in range(4,0,-1):
    print(i)
# Out:
# 4
# 3
# 2
# 1
